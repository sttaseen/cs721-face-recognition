# %%
import cv2
from IPython.display import display, Image
import time
import torch
import torch.nn as nn
from torchvision import models, transforms
from PIL import Image as PILImage
import os

# Initialize the camera using OpenCV.
camera = cv2.VideoCapture(0)
camera.set(cv2.CAP_PROP_FRAME_WIDTH, 320)
camera.set(cv2.CAP_PROP_FRAME_HEIGHT, 240)
display_handle = display(None, display_id=True)
if not camera.isOpened():
    print("Error: Could not open webcam.")
else:
    print('Webcam ready!')

# Load model and checkpoint
num_classes = 2
checkpoint = './ryan_albaro_uribe_resnet34.pth'
model = models.resnet34(pretrained=False)
model.fc = nn.Linear(model.fc.in_features, num_classes)
# model.load_state_dict(torch.load(checkpoint))

# using GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Define the transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize the image
    transforms.ToTensor(),  # Convert the image to a PyTorch tensor
    transforms.Normalize(mean=[0.436, 0.385, 0.345], std=[0.296, 0.270, 0.261])  # Normalize
])

# Set model to evaluation mode
model.eval()

# Create a directory to save photos if it doesn't exist
output_dir = './captured_images'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Camera capture loop
with torch.no_grad():
    image_count = 0  # Counter for saved images
    while camera.isOpened():
        try:
            # Read the camera image
            ret, frame = camera.read()
            if not ret:
                print("Failed to capture frame")
                break

            # Convert to PIL Image for transformations
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            pil_image = PILImage.fromarray(frame_rgb)

            # Apply transformations
            transformed_frame = transform(pil_image).unsqueeze(0).to(device)

            # Get the prediction
            pred = model(transformed_frame)
            pred_class = pred.argmax(1).item()  # Get the predicted class index

            # Save the frame to the output directory every 5 seconds
            image_filename = f"{output_dir}/photo_{image_count}.jpeg"
            cv2.imwrite(image_filename, frame)
            print(f"Saved image: {image_filename}")

            # Increment the image count for the next save
            image_count += 1

            # Display the frame in the notebook (optional)
            _, jpeg_frame = cv2.imencode('.jpeg', frame)
            display_handle.update(Image(data=jpeg_frame.tobytes()))

            # Wait for 5 seconds before capturing the next image
            time.sleep(5)

        except KeyboardInterrupt:
            break

# Clean up camera resources
camera.release()
cv2.destroyAllWindows()
# Out:
# Webcam ready!
# Saved image: ./captured_images/photo_0.jpeg
# Saved image: ./captured_images/photo_1.jpeg
# Saved image: ./captured_images/photo_2.jpeg
# Saved image: ./captured_images/photo_3.jpeg
# Saved image: ./captured_images/photo_4.jpeg
# Saved image: ./captured_images/photo_5.jpeg
# Saved image: ./captured_images/photo_6.jpeg
# Saved image: ./captured_images/photo_7.jpeg
# Saved image: ./captured_images/photo_8.jpeg
# Saved image: ./captured_images/photo_9.jpeg
# Saved image: ./captured_images/photo_10.jpeg
# Saved image: ./captured_images/photo_11.jpeg
# Saved image: ./captured_images/photo_12.jpeg
# Saved image: ./captured_images/photo_13.jpeg
# Saved image: ./captured_images/photo_14.jpeg
# Saved image: ./captured_images/photo_15.jpeg
# Saved image: ./captured_images/photo_16.jpeg
# Saved image: ./captured_images/photo_17.jpeg
# Saved image: ./captured_images/photo_18.jpeg
# Saved image: ./captured_images/photo_19.jpeg
# Saved image: ./captured_images/photo_20.jpeg
# Saved image: ./captured_images/photo_21.jpeg
# Saved image: ./captured_images/photo_22.jpeg
# Saved image: ./captured_images/photo_23.jpeg
# Saved image: ./captured_images/photo_24.jpeg
# Saved image: ./captured_images/photo_25.jpeg
# Saved image: ./captured_images/photo_26.jpeg
# Saved image: ./captured_images/photo_27.jpeg
# Saved image: ./captured_images/photo_28.jpeg
# Saved image: ./captured_images/photo_29.jpeg
# Saved image: ./captured_images/photo_30.jpeg
# Saved image: ./captured_images/photo_31.jpeg
# Saved image: ./captured_images/photo_32.jpeg
# Saved image: ./captured_images/photo_33.jpeg
# Saved image: ./captured_images/photo_34.jpeg
# Saved image: ./captured_images/photo_35.jpeg
# Saved image: ./captured_images/photo_36.jpeg
# Saved image: ./captured_images/photo_37.jpeg
# Saved image: ./captured_images/photo_38.jpeg
# Saved image: ./captured_images/photo_39.jpeg
# Saved image: ./captured_images/photo_40.jpeg
# Saved image: ./captured_images/photo_41.jpeg
# Saved image: ./captured_images/photo_42.jpeg
# Saved image: ./captured_images/photo_43.jpeg
# Saved image: ./captured_images/photo_44.jpeg
# Saved image: ./captured_images/photo_45.jpeg
# Saved image: ./captured_images/photo_46.jpeg
# Saved image: ./captured_images/photo_47.jpeg
# Saved image: ./captured_images/photo_48.jpeg
# Saved image: ./captured_images/photo_49.jpeg
# Saved image: ./captured_images/photo_50.jpeg
# Saved image: ./captured_images/photo_51.jpeg
# Saved image: ./captured_images/photo_52.jpeg
# Saved image: ./captured_images/photo_53.jpeg
# Saved image: ./captured_images/photo_54.jpeg
# Saved image: ./captured_images/photo_55.jpeg
# Saved image: ./captured_images/photo_56.jpeg
# Saved image: ./captured_images/photo_57.jpeg
# Saved image: ./captured_images/photo_58.jpeg
# Saved image: ./captured_images/photo_59.jpeg
# Saved image: ./captured_images/photo_60.jpeg
# Saved image: ./captured_images/photo_61.jpeg
# Saved image: ./captured_images/photo_62.jpeg
# Saved image: ./captured_images/photo_63.jpeg
# Saved image: ./captured_images/photo_64.jpeg
# Saved image: ./captured_images/photo_65.jpeg
# Saved image: ./captured_images/photo_66.jpeg
# Saved image: ./captured_images/photo_67.jpeg
# Saved image: ./captured_images/photo_68.jpeg
# Saved image: ./captured_images/photo_69.jpeg
# Saved image: ./captured_images/photo_70.jpeg
# Saved image: ./captured_images/photo_71.jpeg
# Saved image: ./captured_images/photo_72.jpeg
# Saved image: ./captured_images/photo_73.jpeg
# Saved image: ./captured_images/photo_74.jpeg
# Saved image: ./captured_images/photo_75.jpeg
# Saved image: ./captured_images/photo_76.jpeg
# Saved image: ./captured_images/photo_77.jpeg
# Saved image: ./captured_images/photo_78.jpeg
# Saved image: ./captured_images/photo_79.jpeg
# Saved image: ./captured_images/photo_80.jpeg
# Saved image: ./captured_images/photo_81.jpeg
# Saved image: ./captured_images/photo_82.jpeg
# Saved image: ./captured_images/photo_83.jpeg
# Saved image: ./captured_images/photo_84.jpeg
# Saved image: ./captured_images/photo_85.jpeg
# Saved image: ./captured_images/photo_86.jpeg
# Saved image: ./captured_images/photo_87.jpeg
# Saved image: ./captured_images/photo_88.jpeg
# Saved image: ./captured_images/photo_89.jpeg
# Saved image: ./captured_images/photo_90.jpeg
# Saved image: ./captured_images/photo_91.jpeg
# Saved image: ./captured_images/photo_92.jpeg
# Saved image: ./captured_images/photo_93.jpeg
# Saved image: ./captured_images/photo_94.jpeg
# Saved image: ./captured_images/photo_95.jpeg
# Saved image: ./captured_images/photo_96.jpeg
# Saved image: ./captured_images/photo_97.jpeg
# Saved image: ./captured_images/photo_98.jpeg
# Saved image: ./captured_images/photo_99.jpeg
