# %% [markdown]
# ## Imports

# %%
import torch
from torch import nn, optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
import numpy as np
import random

# %% [markdown]
# ## Set seed for reproducibility

# %%
def set_seed(seed):
    """
    Set the seed for reproducibility.

    Args:
        seed (int): Seed value to set for random number generation.
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

# Set seed to be 42
set_seed(42)

# %% [markdown]
# ## Resnet-18

# %% [markdown]
# ## 5-fold Cross Validation

# %%
# Hyperparameters
best_hyperparams = {'lr': 0.01, 'batch_size': 4}

# %%
import torch
from torch import nn, optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
import numpy as np

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define the EfficientNet model to use
def create_efficientnet_model(num_classes):
    # Load the EfficientNet-B2 model
    model = models.efficientnet_b2(pretrained=False)
    # Replace the classifier layer
    model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
    return model.to(device)
    
# Define transforms
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.43636918, 0.38563913, 0.34477144],
                         std=[0.29639485, 0.2698132, 0.26158142])
])

# Set the dataset folder
dataset_folder = '../data/lfw/'

# Load datasets
dataset = datasets.ImageFolder(root=dataset_folder, transform=transform)

# Get targets and number of classes
targets = np.array(dataset.targets)
num_classes = len(torch.unique(torch.tensor(targets)))

# Define 10-fold stratified cross-validation
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Early stopping criteria
early_stopping_patience = 5

# List to store the results for each fold
fold_results = []

# 10-fold cross-validation loop
for fold, (train_idx, val_idx) in enumerate(skf.split(np.zeros(len(targets)), targets)):
    print(f'Fold {fold+1}')
    
    # Create training and validation subsets
    train_subset = Subset(dataset, train_idx)
    val_subset = Subset(dataset, val_idx)
    
    # Create data loaders
    train_loader = DataLoader(train_subset, batch_size=best_hyperparams['batch_size'], shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=best_hyperparams['batch_size'], shuffle=False)
    
    # Initialize model, loss function, and optimizer
    model = create_efficientnet_model(num_classes)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=best_hyperparams['lr'])
    
    # Initialize early stopping parameters
    best_val_loss = float('inf')
    early_stopping_counter = 0
    best_val_acc = 0
    best_f1 = 0
    
    # Training loop
    for epoch in range(100):  # Modify number of epochs if needed
        model.train()
        running_loss = 0.0
        correct_preds = 0
        
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * images.size(0)
            correct_preds += (outputs.argmax(1) == labels).sum().item()
        
        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = correct_preds / len(train_loader.dataset)
        
        # Validation loop
        model.eval()
        val_loss = 0.0
        val_correct = 0
        all_labels = []
        all_preds = []
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                val_correct += (outputs.argmax(1) == labels).sum().item()
                
                # Store predictions and labels for F1 score calculation
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(outputs.argmax(1).cpu().numpy())
        
        val_loss /= len(val_loader.dataset)
        val_acc = val_correct / len(val_loader.dataset)
        
        # Calculate F1 score (macro-average)
        f1 = f1_score(all_labels, all_preds, average='macro')
        
        print(f'Epoch {epoch+1} - Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}')
        print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}, F1 Score: {f1:.4f}')
        
        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_val_acc = val_acc
            best_f1 = f1
            early_stopping_counter = 0
            torch.save(model.state_dict(), f'best_model_fold_{fold+1}.pth')  # Save the best model for this fold
        else:
            early_stopping_counter += 1
        
        if early_stopping_counter >= early_stopping_patience:
            print(f'Early stopping triggered after {early_stopping_counter} epochs without improvement.')
            break
    
    # Store the best validation loss, accuracy, and F1 score for this fold
    fold_results.append({'fold': fold+1, 'val_loss': best_val_loss, 'val_acc': best_val_acc, 'f1_score': best_f1})

# Print cross-validation results
print("\nCross-validation results:")
avg_val_loss = np.mean([result['val_loss'] for result in fold_results])
avg_val_acc = np.mean([result['val_acc'] for result in fold_results])
avg_f1_score = np.mean([result['f1_score'] for result in fold_results])

for result in fold_results:
    print(f"Fold {result['fold']}: Validation Loss = {result['val_loss']:.4f}, Validation Accuracy = {result['val_acc']:.4f}, F1 Score = {result['f1_score']:.4f}")

print(f"\nAverage Validation Loss: {avg_val_loss:.4f}")
print(f"Average Validation Accuracy: {avg_val_acc:.4f}")
print(f"Average F1 Score: {avg_f1_score:.4f}")
# Out:
# Fold 1
# Epoch 1 - Loss: 2.3670, Accuracy: 0.2863
# Validation Loss: 2.0726, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 2 - Loss: 2.0952, Accuracy: 0.3443
# Validation Loss: 2.0726, Validation Accuracy: 0.3151, F1 Score: 0.0646
# Epoch 3 - Loss: 2.0168, Accuracy: 0.3359
# Validation Loss: 1.9535, Validation Accuracy: 0.3082, F1 Score: 0.0700
# Epoch 4 - Loss: 1.9571, Accuracy: 0.3336
# Validation Loss: 1.9291, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 5 - Loss: 1.9171, Accuracy: 0.3466
# Validation Loss: 1.7916, Validation Accuracy: 0.3699, F1 Score: 0.0785
# Epoch 6 - Loss: 1.9019, Accuracy: 0.3466
# Validation Loss: 1.7360, Validation Accuracy: 0.3699, F1 Score: 0.0910
# Epoch 7 - Loss: 1.7936, Accuracy: 0.3611
# Validation Loss: 1.6316, Validation Accuracy: 0.4384, F1 Score: 0.1422
# Epoch 8 - Loss: 1.8486, Accuracy: 0.3618
# Validation Loss: 1.6254, Validation Accuracy: 0.4178, F1 Score: 0.1249
# Epoch 9 - Loss: 1.7779, Accuracy: 0.3718
# Validation Loss: 1.7465, Validation Accuracy: 0.3425, F1 Score: 0.1778
# Epoch 10 - Loss: 1.7436, Accuracy: 0.3733
# Validation Loss: 1.6386, Validation Accuracy: 0.3356, F1 Score: 0.1276
# Epoch 11 - Loss: 1.7117, Accuracy: 0.4053
# Validation Loss: 1.9164, Validation Accuracy: 0.1301, F1 Score: 0.0513
# Epoch 12 - Loss: 1.7232, Accuracy: 0.4046
# Validation Loss: 1.3765, Validation Accuracy: 0.5068, F1 Score: 0.2317
# Epoch 13 - Loss: 1.5838, Accuracy: 0.4389
# Validation Loss: 1.5527, Validation Accuracy: 0.4315, F1 Score: 0.1711
# Epoch 14 - Loss: 1.5854, Accuracy: 0.4458
# Validation Loss: 1.4820, Validation Accuracy: 0.4795, F1 Score: 0.2624
# Epoch 15 - Loss: 1.5598, Accuracy: 0.4580
# Validation Loss: 1.3083, Validation Accuracy: 0.5274, F1 Score: 0.2213
# Epoch 16 - Loss: 1.4944, Accuracy: 0.4847
# Validation Loss: 1.3603, Validation Accuracy: 0.4932, F1 Score: 0.2414
# Epoch 17 - Loss: 1.4689, Accuracy: 0.4885
# Validation Loss: 1.2960, Validation Accuracy: 0.5548, F1 Score: 0.2869
# Epoch 18 - Loss: 1.4076, Accuracy: 0.5076
# Validation Loss: 1.1392, Validation Accuracy: 0.6096, F1 Score: 0.3390
# Epoch 19 - Loss: 1.3500, Accuracy: 0.5137
# Validation Loss: 2.1284, Validation Accuracy: 0.3904, F1 Score: 0.1660
# Epoch 20 - Loss: 1.3436, Accuracy: 0.5382
# Epoch 33 - Loss: 0.7474, Accuracy: 0.7399
# Validation Loss: 1.3160, Validation Accuracy: 0.6207, F1 Score: 0.4741
# Early stopping triggered after 5 epochs without improvement.
# Fold 9
# Epoch 1 - Loss: 2.3751, Accuracy: 0.2906
# Validation Loss: 2.0983, Validation Accuracy: 0.2897, F1 Score: 0.0522
# Epoch 2 - Loss: 2.0787, Accuracy: 0.3394
# Validation Loss: 2.0329, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 3 - Loss: 2.0674, Accuracy: 0.3341
# Validation Loss: 2.3801, Validation Accuracy: 0.2000, F1 Score: 0.0483
# Epoch 4 - Loss: 2.0793, Accuracy: 0.3371
# Validation Loss: 2.0486, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 5 - Loss: 2.0778, Accuracy: 0.3486
# Validation Loss: 2.0249, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 6 - Loss: 2.0592, Accuracy: 0.3516
# Validation Loss: 1.9931, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 7 - Loss: 2.0674, Accuracy: 0.3356
# Validation Loss: 2.0044, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 8 - Loss: 2.0560, Accuracy: 0.3417
# Validation Loss: 2.0238, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 9 - Loss: 2.0599, Accuracy: 0.3425
# Validation Loss: 2.0133, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 10 - Loss: 2.0674, Accuracy: 0.3448
# Validation Loss: 2.0984, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 11 - Loss: 2.0575, Accuracy: 0.3387
# Validation Loss: 1.9966, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Early stopping triggered after 5 epochs without improvement.
# Fold 10
# Epoch 1 - Loss: 2.3203, Accuracy: 0.3074
# Validation Loss: 2.1246, Validation Accuracy: 0.2966, F1 Score: 0.0662
# Epoch 2 - Loss: 2.0954, Accuracy: 0.3432
# Validation Loss: 2.0236, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 3 - Loss: 2.0795, Accuracy: 0.3356
# Validation Loss: 2.0253, Validation Accuracy: 0.3655, F1 Score: 0.0647
# Epoch 4 - Loss: 2.0668, Accuracy: 0.3509
# Validation Loss: 2.0334, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 5 - Loss: 2.0689, Accuracy: 0.3494
# Validation Loss: 2.0860, Validation Accuracy: 0.3448, F1 Score: 0.0625
# Epoch 6 - Loss: 2.0590, Accuracy: 0.3463
# Validation Loss: 2.0658, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 7 - Loss: 2.0612, Accuracy: 0.3524
# Validation Loss: 2.1325, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Early stopping triggered after 5 epochs without improvement.
#
# Cross-validation results:
# Fold 1: Validation Loss = 1.1392, Validation Accuracy = 0.6096, F1 Score = 0.3390
# Fold 2: Validation Loss = 2.0011, Validation Accuracy = 0.3630, F1 Score = 0.0533
# Fold 3: Validation Loss = 1.9928, Validation Accuracy = 0.3630, F1 Score = 0.0533
# Fold 4: Validation Loss = 1.9977, Validation Accuracy = 0.3630, F1 Score = 0.0533
# Fold 5: Validation Loss = 2.0246, Validation Accuracy = 0.3630, F1 Score = 0.0533
# Fold 6: Validation Loss = 1.9975, Validation Accuracy = 0.3630, F1 Score = 0.0533
# Fold 7: Validation Loss = 1.9986, Validation Accuracy = 0.3655, F1 Score = 0.0535
# Fold 8: Validation Loss = 0.8047, Validation Accuracy = 0.7103, F1 Score = 0.5303
# Fold 9: Validation Loss = 1.9931, Validation Accuracy = 0.3655, F1 Score = 0.0535
# Fold 10: Validation Loss = 2.0236, Validation Accuracy = 0.3655, F1 Score = 0.0535
#
# Average Validation Loss: 1.7973
# Average Validation Accuracy: 0.4232
# Average F1 Score: 0.1296
