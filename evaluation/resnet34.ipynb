# %% [markdown]
# ## Imports

# %%
import torch
from torch import nn, optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
import numpy as np
import random

# %% [markdown]
# ## Set seed for reproducibility

# %%
def set_seed(seed):
    """
    Set the seed for reproducibility.

    Args:
        seed (int): Seed value to set for random number generation.
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

# Set seed to be 42
set_seed(42)

# %% [markdown]
# ## Resnet-34

# %% [markdown]
# ## 5-fold Cross Validation

# %%
# Hyperparameters
best_hyperparams = {'lr': 0.01, 'batch_size': 16}

# %%
# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Create the ResNet18 model
def create_resnet_model(num_classes):
    model = models.resnet34(pretrained=False)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    return model.to(device)

# Define transforms
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.43636918, 0.38563913, 0.34477144],
                         std=[0.29639485, 0.2698132, 0.26158142])
])

# Set the dataset folder
dataset_folder = '../data/lfw/'

# Load datasets
dataset = datasets.ImageFolder(root=dataset_folder, transform=transform)

# Get targets and number of classes
targets = np.array(dataset.targets)
num_classes = len(torch.unique(torch.tensor(targets)))

# Define 10-fold stratified cross-validation
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Early stopping criteria
early_stopping_patience = 5

# List to store the results for each fold
fold_results = []

# 10-fold cross-validation loop
for fold, (train_idx, val_idx) in enumerate(skf.split(np.zeros(len(targets)), targets)):
    print(f'Fold {fold+1}')
    
    # Create training and validation subsets
    train_subset = Subset(dataset, train_idx)
    val_subset = Subset(dataset, val_idx)
    
    # Create data loaders
    train_loader = DataLoader(train_subset, batch_size=best_hyperparams['batch_size'], shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=best_hyperparams['batch_size'], shuffle=False)
    
    # Initialize model, loss function, and optimizer
    model = create_resnet_model(num_classes)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=best_hyperparams['lr'])
    
    # Initialize early stopping parameters
    best_val_loss = float('inf')
    early_stopping_counter = 0
    best_val_acc = 0
    best_f1 = 0
    
    # Training loop
    for epoch in range(100):  # Modify number of epochs if needed
        model.train()
        running_loss = 0.0
        correct_preds = 0
        
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * images.size(0)
            correct_preds += (outputs.argmax(1) == labels).sum().item()
        
        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = correct_preds / len(train_loader.dataset)
        
        # Validation loop
        model.eval()
        val_loss = 0.0
        val_correct = 0
        all_labels = []
        all_preds = []
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                val_correct += (outputs.argmax(1) == labels).sum().item()
                
                # Store predictions and labels for F1 score calculation
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(outputs.argmax(1).cpu().numpy())
        
        val_loss /= len(val_loader.dataset)
        val_acc = val_correct / len(val_loader.dataset)
        
        # Calculate F1 score (macro-average)
        f1 = f1_score(all_labels, all_preds, average='macro')
        
        print(f'Epoch {epoch+1} - Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}')
        print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}, F1 Score: {f1:.4f}')
        
        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_val_acc = val_acc
            best_f1 = f1
            early_stopping_counter = 0
            torch.save(model.state_dict(), f'best_model_fold_{fold+1}.pth')  # Save the best model for this fold
        else:
            early_stopping_counter += 1
        
        if early_stopping_counter >= early_stopping_patience:
            print(f'Early stopping triggered after {early_stopping_counter} epochs without improvement.')
            break
    
    # Store the best validation loss, accuracy, and F1 score for this fold
    fold_results.append({'fold': fold+1, 'val_loss': best_val_loss, 'val_acc': best_val_acc, 'f1_score': best_f1})

# Print cross-validation results
print("\nCross-validation results:")
avg_val_loss = np.mean([result['val_loss'] for result in fold_results])
avg_val_acc = np.mean([result['val_acc'] for result in fold_results])
avg_f1_score = np.mean([result['f1_score'] for result in fold_results])

for result in fold_results:
    print(f"Fold {result['fold']}: Validation Loss = {result['val_loss']:.4f}, Validation Accuracy = {result['val_acc']:.4f}, F1 Score = {result['f1_score']:.4f}")

print(f"\nAverage Validation Loss: {avg_val_loss:.4f}")
print(f"Average Validation Accuracy: {avg_val_acc:.4f}")
print(f"Average F1 Score: {avg_f1_score:.4f}")
# Out:
# Fold 1
# Epoch 1 - Loss: 2.5661, Accuracy: 0.3061
# Validation Loss: 2.2500, Validation Accuracy: 0.3356, F1 Score: 0.0599
# Epoch 2 - Loss: 2.0516, Accuracy: 0.3542
# Validation Loss: 2.0138, Validation Accuracy: 0.3562, F1 Score: 0.0531
# Epoch 3 - Loss: 2.0057, Accuracy: 0.3634
# Validation Loss: 1.9798, Validation Accuracy: 0.3699, F1 Score: 0.0806
# Epoch 4 - Loss: 1.9866, Accuracy: 0.3634
# Validation Loss: 3.9987, Validation Accuracy: 0.2671, F1 Score: 0.0629
# Epoch 5 - Loss: 1.9705, Accuracy: 0.3695
# Validation Loss: 2.4608, Validation Accuracy: 0.2877, F1 Score: 0.0861
# Epoch 6 - Loss: 1.9286, Accuracy: 0.3672
# Validation Loss: 1.9882, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 7 - Loss: 1.8764, Accuracy: 0.3695
# Validation Loss: 1.9170, Validation Accuracy: 0.3973, F1 Score: 0.1422
# Epoch 8 - Loss: 1.7908, Accuracy: 0.3908
# Validation Loss: 1.8766, Validation Accuracy: 0.3699, F1 Score: 0.1728
# Epoch 9 - Loss: 1.7447, Accuracy: 0.3878
# Validation Loss: 2.6675, Validation Accuracy: 0.1781, F1 Score: 0.0985
# Epoch 10 - Loss: 1.6779, Accuracy: 0.4198
# Validation Loss: 1.5363, Validation Accuracy: 0.4932, F1 Score: 0.2863
# Epoch 11 - Loss: 1.5017, Accuracy: 0.4756
# Validation Loss: 1.6890, Validation Accuracy: 0.4315, F1 Score: 0.2912
# Epoch 12 - Loss: 1.4326, Accuracy: 0.5053
# Validation Loss: 1.3460, Validation Accuracy: 0.5685, F1 Score: 0.3750
# Epoch 13 - Loss: 1.3254, Accuracy: 0.5489
# Validation Loss: 1.3729, Validation Accuracy: 0.5548, F1 Score: 0.3453
# Epoch 14 - Loss: 1.1865, Accuracy: 0.5977
# Validation Loss: 1.5429, Validation Accuracy: 0.5411, F1 Score: 0.3079
# Epoch 15 - Loss: 1.0921, Accuracy: 0.6221
# Validation Loss: 1.1952, Validation Accuracy: 0.5822, F1 Score: 0.3509
# Epoch 16 - Loss: 0.9848, Accuracy: 0.6580
# Validation Loss: 1.9783, Validation Accuracy: 0.4521, F1 Score: 0.2910
# Epoch 17 - Loss: 0.8989, Accuracy: 0.6847
# Validation Loss: 1.3001, Validation Accuracy: 0.5479, F1 Score: 0.3536
# Epoch 18 - Loss: 0.7404, Accuracy: 0.7405
# Validation Loss: 1.1186, Validation Accuracy: 0.6301, F1 Score: 0.4468
# Epoch 19 - Loss: 0.6863, Accuracy: 0.7618
# Validation Loss: 0.8268, Validation Accuracy: 0.7192, F1 Score: 0.5549
# Epoch 20 - Loss: 0.6540, Accuracy: 0.7817
# Validation Loss: 0.6211, Validation Accuracy: 0.8082, F1 Score: 0.7372
# Epoch 21 - Loss: 0.4866, Accuracy: 0.8313
# Validation Loss: 0.9735, Validation Accuracy: 0.6918, F1 Score: 0.5868
# Epoch 22 - Loss: 0.3796, Accuracy: 0.8763
# Validation Loss: 0.5867, Validation Accuracy: 0.8151, F1 Score: 0.7654
# Epoch 23 - Loss: 0.3453, Accuracy: 0.8679
# Validation Loss: 1.3232, Validation Accuracy: 0.6781, F1 Score: 0.5680
# Epoch 24 - Loss: 0.2212, Accuracy: 0.9221
# Validation Loss: 0.5637, Validation Accuracy: 0.8014, F1 Score: 0.7095
# Epoch 25 - Loss: 0.2332, Accuracy: 0.9183
# Validation Loss: 0.6897, Validation Accuracy: 0.7877, F1 Score: 0.7384
# Epoch 26 - Loss: 0.2087, Accuracy: 0.9298
# Validation Loss: 0.9462, Validation Accuracy: 0.7260, F1 Score: 0.6639
# Epoch 27 - Loss: 0.1405, Accuracy: 0.9557
# Validation Loss: 0.4127, Validation Accuracy: 0.8630, F1 Score: 0.7885
# Epoch 28 - Loss: 0.0395, Accuracy: 0.9885
# Validation Loss: 0.7910, Validation Accuracy: 0.8082, F1 Score: 0.7460
# Epoch 29 - Loss: 0.1104, Accuracy: 0.9649
# Validation Loss: 0.8301, Validation Accuracy: 0.7671, F1 Score: 0.7018
# Epoch 30 - Loss: 0.1095, Accuracy: 0.9672
# Validation Loss: 0.6301, Validation Accuracy: 0.8219, F1 Score: 0.7673
# Epoch 31 - Loss: 0.0506, Accuracy: 0.9893
# Validation Loss: 0.8624, Validation Accuracy: 0.7808, F1 Score: 0.7102
# Epoch 32 - Loss: 0.0789, Accuracy: 0.9702
# Validation Loss: 1.3831, Validation Accuracy: 0.6575, F1 Score: 0.6075
# Early stopping triggered after 5 epochs without improvement.
# Fold 2
# Epoch 1 - Loss: 2.4975, Accuracy: 0.3084
# Validation Loss: 2.1292, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 2 - Loss: 2.0438, Accuracy: 0.3626
# Validation Loss: 4.9803, Validation Accuracy: 0.3082, F1 Score: 0.0905
# Epoch 3 - Loss: 1.9894, Accuracy: 0.3641
# Validation Loss: 1.9831, Validation Accuracy: 0.3562, F1 Score: 0.0594
# Epoch 4 - Loss: 1.9566, Accuracy: 0.3687
# Validation Loss: 1.9453, Validation Accuracy: 0.3767, F1 Score: 0.1081
# Epoch 5 - Loss: 1.9435, Accuracy: 0.3687
# Validation Loss: 1.8967, Validation Accuracy: 0.3493, F1 Score: 0.0923
# Epoch 6 - Loss: 1.8808, Accuracy: 0.3794
# Validation Loss: 1.7643, Validation Accuracy: 0.3904, F1 Score: 0.1335
# Epoch 7 - Loss: 1.8042, Accuracy: 0.3855
# Validation Loss: 1.6624, Validation Accuracy: 0.4178, F1 Score: 0.1752
# Epoch 8 - Loss: 1.6708, Accuracy: 0.4237
# Validation Loss: 1.8760, Validation Accuracy: 0.4178, F1 Score: 0.1949
# Epoch 9 - Loss: 1.6130, Accuracy: 0.4374
# Validation Loss: 1.6552, Validation Accuracy: 0.4384, F1 Score: 0.1878
# Epoch 10 - Loss: 1.5074, Accuracy: 0.4771
# Validation Loss: 1.7226, Validation Accuracy: 0.4315, F1 Score: 0.2642
# Epoch 11 - Loss: 1.3717, Accuracy: 0.5183
# Validation Loss: 2.0946, Validation Accuracy: 0.3973, F1 Score: 0.1303
# Epoch 12 - Loss: 1.2999, Accuracy: 0.5473
# Validation Loss: 1.2629, Validation Accuracy: 0.5548, F1 Score: 0.3252
# Epoch 13 - Loss: 1.1549, Accuracy: 0.5908
# Validation Loss: 1.7074, Validation Accuracy: 0.4178, F1 Score: 0.1590
# Epoch 14 - Loss: 1.0331, Accuracy: 0.6336
# Validation Loss: 1.4326, Validation Accuracy: 0.5548, F1 Score: 0.3626
# Epoch 15 - Loss: 0.8816, Accuracy: 0.6817
# Validation Loss: 1.2705, Validation Accuracy: 0.6096, F1 Score: 0.3896
# Epoch 16 - Loss: 0.7236, Accuracy: 0.7504
# Validation Loss: 1.3684, Validation Accuracy: 0.5685, F1 Score: 0.3598
# Epoch 17 - Loss: 0.6135, Accuracy: 0.7832
# Validation Loss: 1.1402, Validation Accuracy: 0.6575, F1 Score: 0.5331
# Epoch 18 - Loss: 0.5747, Accuracy: 0.7916
# Validation Loss: 1.1367, Validation Accuracy: 0.6164, F1 Score: 0.4872
# Epoch 19 - Loss: 0.4274, Accuracy: 0.8412
# Validation Loss: 1.4713, Validation Accuracy: 0.6233, F1 Score: 0.5135
# Epoch 20 - Loss: 0.3984, Accuracy: 0.8542
# Validation Loss: 1.1529, Validation Accuracy: 0.6575, F1 Score: 0.5911
# Epoch 21 - Loss: 0.2802, Accuracy: 0.9107
# Validation Loss: 1.3344, Validation Accuracy: 0.6918, F1 Score: 0.6103
# Epoch 22 - Loss: 0.2824, Accuracy: 0.9069
# Validation Loss: 0.6790, Validation Accuracy: 0.8014, F1 Score: 0.7423
# Epoch 23 - Loss: 0.2490, Accuracy: 0.9183
# Validation Loss: 0.7130, Validation Accuracy: 0.7945, F1 Score: 0.7274
# Epoch 24 - Loss: 0.1686, Accuracy: 0.9481
# Validation Loss: 0.6677, Validation Accuracy: 0.8219, F1 Score: 0.7111
# Epoch 25 - Loss: 0.1165, Accuracy: 0.9641
# Validation Loss: 0.8758, Validation Accuracy: 0.8151, F1 Score: 0.7471
# Epoch 26 - Loss: 0.1801, Accuracy: 0.9321
# Validation Loss: 1.1104, Validation Accuracy: 0.7055, F1 Score: 0.6272
# Epoch 27 - Loss: 0.1448, Accuracy: 0.9473
# Validation Loss: 0.6807, Validation Accuracy: 0.8082, F1 Score: 0.7242
# Epoch 28 - Loss: 0.0384, Accuracy: 0.9916
# Validation Loss: 0.8304, Validation Accuracy: 0.8219, F1 Score: 0.7283
# Epoch 29 - Loss: 0.0465, Accuracy: 0.9840
# Validation Loss: 0.8477, Validation Accuracy: 0.8014, F1 Score: 0.7717
# Early stopping triggered after 5 epochs without improvement.
# Fold 3
# Epoch 1 - Loss: 2.4966, Accuracy: 0.3282
# Validation Loss: 2.1607, Validation Accuracy: 0.3425, F1 Score: 0.0524
# Epoch 2 - Loss: 2.0098, Accuracy: 0.3595
# Validation Loss: 2.0101, Validation Accuracy: 0.3562, F1 Score: 0.0528
# Epoch 3 - Loss: 1.9982, Accuracy: 0.3649
# Validation Loss: 1.9873, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 4 - Loss: 1.9847, Accuracy: 0.3641
# Validation Loss: 1.9659, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 5 - Loss: 1.9740, Accuracy: 0.3641
# Validation Loss: 1.9801, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 6 - Loss: 1.9545, Accuracy: 0.3626
# Validation Loss: 1.9968, Validation Accuracy: 0.3699, F1 Score: 0.0970
# Epoch 7 - Loss: 1.9415, Accuracy: 0.3649
# Validation Loss: 2.0696, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 8 - Loss: 1.9324, Accuracy: 0.3618
# Validation Loss: 1.9835, Validation Accuracy: 0.3767, F1 Score: 0.0892
# Epoch 9 - Loss: 1.8934, Accuracy: 0.3634
# Validation Loss: 2.0715, Validation Accuracy: 0.3699, F1 Score: 0.1639
# Early stopping triggered after 5 epochs without improvement.
# Fold 4
# Epoch 1 - Loss: 2.5754, Accuracy: 0.3389
# Validation Loss: 3.4167, Validation Accuracy: 0.3288, F1 Score: 0.0719
# Epoch 2 - Loss: 2.0476, Accuracy: 0.3527
# Validation Loss: 2.0029, Validation Accuracy: 0.3562, F1 Score: 0.0528
# Epoch 3 - Loss: 1.9948, Accuracy: 0.3634
# Validation Loss: 1.9847, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 4 - Loss: 1.9814, Accuracy: 0.3634
# Validation Loss: 1.9814, Validation Accuracy: 0.3562, F1 Score: 0.0597
# Epoch 5 - Loss: 1.9860, Accuracy: 0.3611
# Validation Loss: 1.9675, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 6 - Loss: 1.9777, Accuracy: 0.3641
# Validation Loss: 1.9246, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 7 - Loss: 1.9599, Accuracy: 0.3611
# Validation Loss: 1.9228, Validation Accuracy: 0.3699, F1 Score: 0.0783
# Epoch 8 - Loss: 1.9591, Accuracy: 0.3626
# Validation Loss: 1.9423, Validation Accuracy: 0.3630, F1 Score: 0.0535
# Epoch 9 - Loss: 1.9358, Accuracy: 0.3672
# Validation Loss: 1.9301, Validation Accuracy: 0.3699, F1 Score: 0.0815
# Epoch 10 - Loss: 1.9295, Accuracy: 0.3649
# Validation Loss: 1.9386, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 11 - Loss: 1.9172, Accuracy: 0.3611
# Validation Loss: 1.9508, Validation Accuracy: 0.3630, F1 Score: 0.0535
# Epoch 12 - Loss: 1.9154, Accuracy: 0.3656
# Validation Loss: 1.8872, Validation Accuracy: 0.3493, F1 Score: 0.0844
# Epoch 13 - Loss: 1.8879, Accuracy: 0.3641
# Validation Loss: 1.9049, Validation Accuracy: 0.3562, F1 Score: 0.0680
# Epoch 14 - Loss: 1.8646, Accuracy: 0.3748
# Validation Loss: 1.9095, Validation Accuracy: 0.3562, F1 Score: 0.0754
# Epoch 15 - Loss: 1.8679, Accuracy: 0.3656
# Validation Loss: 1.8223, Validation Accuracy: 0.3836, F1 Score: 0.1002
# Epoch 16 - Loss: 1.8229, Accuracy: 0.3763
# Validation Loss: 1.9818, Validation Accuracy: 0.2740, F1 Score: 0.1008
# Epoch 17 - Loss: 1.7494, Accuracy: 0.3885
# Validation Loss: 2.0106, Validation Accuracy: 0.3630, F1 Score: 0.1768
# Epoch 18 - Loss: 1.6360, Accuracy: 0.4244
# Validation Loss: 1.6420, Validation Accuracy: 0.3973, F1 Score: 0.2106
# Epoch 19 - Loss: 1.4932, Accuracy: 0.4679
# Validation Loss: 1.5716, Validation Accuracy: 0.4110, F1 Score: 0.2082
# Epoch 20 - Loss: 1.3672, Accuracy: 0.5206
# Validation Loss: 1.4315, Validation Accuracy: 0.5411, F1 Score: 0.2908
# Epoch 21 - Loss: 1.1984, Accuracy: 0.5794
# Validation Loss: 2.2019, Validation Accuracy: 0.2945, F1 Score: 0.1864
# Epoch 22 - Loss: 0.9675, Accuracy: 0.6519
# Validation Loss: 1.0921, Validation Accuracy: 0.6575, F1 Score: 0.4802
# Epoch 23 - Loss: 0.8530, Accuracy: 0.7069
# Validation Loss: 0.8885, Validation Accuracy: 0.6849, F1 Score: 0.5324
# Epoch 24 - Loss: 0.7018, Accuracy: 0.7450
# Validation Loss: 1.0633, Validation Accuracy: 0.6849, F1 Score: 0.5452
# Epoch 25 - Loss: 0.5669, Accuracy: 0.7954
# Validation Loss: 1.1193, Validation Accuracy: 0.6370, F1 Score: 0.5066
# Epoch 26 - Loss: 0.3849, Accuracy: 0.8656
# Validation Loss: 0.5883, Validation Accuracy: 0.8288, F1 Score: 0.7356
# Epoch 27 - Loss: 0.3527, Accuracy: 0.8725
# Validation Loss: 0.6763, Validation Accuracy: 0.7945, F1 Score: 0.6687
# Epoch 28 - Loss: 0.2384, Accuracy: 0.9198
# Validation Loss: 0.5882, Validation Accuracy: 0.8219, F1 Score: 0.7058
# Epoch 29 - Loss: 0.2016, Accuracy: 0.9321
# Validation Loss: 0.5809, Validation Accuracy: 0.8082, F1 Score: 0.6830
# Epoch 30 - Loss: 0.1572, Accuracy: 0.9473
# Validation Loss: 0.5585, Validation Accuracy: 0.8288, F1 Score: 0.7214
# Epoch 31 - Loss: 0.1408, Accuracy: 0.9542
# Validation Loss: 0.5427, Validation Accuracy: 0.8425, F1 Score: 0.7627
# Epoch 32 - Loss: 0.1247, Accuracy: 0.9588
# Validation Loss: 0.6194, Validation Accuracy: 0.8014, F1 Score: 0.7352
# Epoch 33 - Loss: 0.0991, Accuracy: 0.9649
# Validation Loss: 0.5252, Validation Accuracy: 0.8493, F1 Score: 0.7576
# Epoch 34 - Loss: 0.0779, Accuracy: 0.9763
# Validation Loss: 0.3622, Validation Accuracy: 0.8767, F1 Score: 0.7989
# Epoch 35 - Loss: 0.0644, Accuracy: 0.9809
# Validation Loss: 0.7065, Validation Accuracy: 0.8219, F1 Score: 0.7372
# Epoch 36 - Loss: 0.0944, Accuracy: 0.9710
# Validation Loss: 0.4067, Validation Accuracy: 0.8562, F1 Score: 0.7647
# Epoch 37 - Loss: 0.0305, Accuracy: 0.9901
# Validation Loss: 0.4736, Validation Accuracy: 0.9041, F1 Score: 0.8431
# Epoch 38 - Loss: 0.0121, Accuracy: 0.9977
# Validation Loss: 0.3580, Validation Accuracy: 0.8836, F1 Score: 0.7989
# Epoch 39 - Loss: 0.0211, Accuracy: 0.9954
# Validation Loss: 0.7032, Validation Accuracy: 0.8562, F1 Score: 0.7916
# Epoch 40 - Loss: 0.0398, Accuracy: 0.9870
# Validation Loss: 0.6594, Validation Accuracy: 0.8493, F1 Score: 0.7566
# Epoch 41 - Loss: 0.0461, Accuracy: 0.9817
# Validation Loss: 0.6607, Validation Accuracy: 0.8288, F1 Score: 0.7685
# Epoch 42 - Loss: 0.0409, Accuracy: 0.9870
# Validation Loss: 0.8196, Validation Accuracy: 0.8219, F1 Score: 0.7572
# Epoch 43 - Loss: 0.0269, Accuracy: 0.9931
# Validation Loss: 0.6203, Validation Accuracy: 0.8562, F1 Score: 0.7740
# Early stopping triggered after 5 epochs without improvement.
# Fold 5
# Epoch 1 - Loss: 2.5400, Accuracy: 0.3336
# Validation Loss: 3.9899, Validation Accuracy: 0.3425, F1 Score: 0.0763
# Epoch 2 - Loss: 2.0214, Accuracy: 0.3603
# Validation Loss: 1.9956, Validation Accuracy: 0.3699, F1 Score: 0.0834
# Epoch 3 - Loss: 1.9971, Accuracy: 0.3672
# Validation Loss: 2.0783, Validation Accuracy: 0.3630, F1 Score: 0.0699
# Epoch 4 - Loss: 2.0128, Accuracy: 0.3573
# Validation Loss: 2.0112, Validation Accuracy: 0.3493, F1 Score: 0.0520
# Epoch 5 - Loss: 1.9792, Accuracy: 0.3641
# Validation Loss: 1.9992, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 6 - Loss: 1.9824, Accuracy: 0.3634
# Validation Loss: 1.9728, Validation Accuracy: 0.3630, F1 Score: 0.0535
# Epoch 7 - Loss: 1.9720, Accuracy: 0.3641
# Validation Loss: 1.9975, Validation Accuracy: 0.3699, F1 Score: 0.0618
# Epoch 8 - Loss: 1.9676, Accuracy: 0.3641
# Validation Loss: 1.9654, Validation Accuracy: 0.3767, F1 Score: 0.0824
# Epoch 9 - Loss: 1.9606, Accuracy: 0.3656
# Validation Loss: 2.0049, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 10 - Loss: 1.9507, Accuracy: 0.3649
# Validation Loss: 1.9060, Validation Accuracy: 0.3836, F1 Score: 0.1031
# Epoch 11 - Loss: 1.9333, Accuracy: 0.3679
# Validation Loss: 1.9365, Validation Accuracy: 0.3699, F1 Score: 0.0760
# Epoch 12 - Loss: 1.8828, Accuracy: 0.3748
# Validation Loss: 1.9389, Validation Accuracy: 0.3699, F1 Score: 0.0760
# Epoch 13 - Loss: 1.7560, Accuracy: 0.4023
# Validation Loss: 5.5103, Validation Accuracy: 0.1644, F1 Score: 0.0622
# Epoch 14 - Loss: 1.6917, Accuracy: 0.4168
# Validation Loss: 1.9810, Validation Accuracy: 0.3151, F1 Score: 0.1816
# Epoch 15 - Loss: 1.4876, Accuracy: 0.4863
# Validation Loss: 1.6177, Validation Accuracy: 0.4110, F1 Score: 0.1507
# Epoch 16 - Loss: 1.2296, Accuracy: 0.5588
# Validation Loss: 1.3903, Validation Accuracy: 0.5890, F1 Score: 0.3940
# Epoch 17 - Loss: 1.1237, Accuracy: 0.5992
# Validation Loss: 1.0750, Validation Accuracy: 0.6301, F1 Score: 0.4082
# Epoch 18 - Loss: 0.8844, Accuracy: 0.6916
# Validation Loss: 1.3810, Validation Accuracy: 0.5890, F1 Score: 0.4195
# Epoch 19 - Loss: 0.7503, Accuracy: 0.7359
# Validation Loss: 1.2853, Validation Accuracy: 0.6301, F1 Score: 0.4944
# Epoch 20 - Loss: 0.6679, Accuracy: 0.7664
# Validation Loss: 0.9924, Validation Accuracy: 0.6781, F1 Score: 0.5653
# Epoch 21 - Loss: 0.5753, Accuracy: 0.7878
# Validation Loss: 2.6729, Validation Accuracy: 0.5342, F1 Score: 0.3942
# Epoch 22 - Loss: 0.5028, Accuracy: 0.8313
# Validation Loss: 0.7211, Validation Accuracy: 0.7329, F1 Score: 0.5761
# Epoch 23 - Loss: 0.3821, Accuracy: 0.8672
# Validation Loss: 0.7911, Validation Accuracy: 0.6986, F1 Score: 0.5921
# Epoch 24 - Loss: 0.3244, Accuracy: 0.8885
# Validation Loss: 0.7251, Validation Accuracy: 0.7397, F1 Score: 0.6507
# Epoch 25 - Loss: 0.2230, Accuracy: 0.9214
# Validation Loss: 2.5091, Validation Accuracy: 0.5274, F1 Score: 0.4079
# Epoch 26 - Loss: 0.2800, Accuracy: 0.9031
# Validation Loss: 0.8552, Validation Accuracy: 0.7808, F1 Score: 0.6336
# Epoch 27 - Loss: 0.1834, Accuracy: 0.9374
# Validation Loss: 0.7900, Validation Accuracy: 0.7808, F1 Score: 0.7660
# Early stopping triggered after 5 epochs without improvement.
# Fold 6
# Epoch 1 - Loss: 2.5187, Accuracy: 0.3214
# Validation Loss: 2.1718, Validation Accuracy: 0.3630, F1 Score: 0.0544
# Epoch 2 - Loss: 2.0310, Accuracy: 0.3527
# Validation Loss: 2.0404, Validation Accuracy: 0.3562, F1 Score: 0.0536
# Epoch 3 - Loss: 2.0023, Accuracy: 0.3618
# Validation Loss: 1.9973, Validation Accuracy: 0.3630, F1 Score: 0.0610
# Epoch 4 - Loss: 1.9850, Accuracy: 0.3618
# Validation Loss: 2.0057, Validation Accuracy: 0.3630, F1 Score: 0.0538
# Epoch 5 - Loss: 1.9783, Accuracy: 0.3634
# Validation Loss: 2.0243, Validation Accuracy: 0.3630, F1 Score: 0.0541
# Epoch 6 - Loss: 1.9713, Accuracy: 0.3641
# Validation Loss: 1.9834, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 7 - Loss: 1.9753, Accuracy: 0.3618
# Validation Loss: 2.2010, Validation Accuracy: 0.3356, F1 Score: 0.0536
# Epoch 8 - Loss: 1.9750, Accuracy: 0.3626
# Validation Loss: 2.0307, Validation Accuracy: 0.3356, F1 Score: 0.0570
# Epoch 9 - Loss: 1.9714, Accuracy: 0.3641
# Validation Loss: 1.9715, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 10 - Loss: 1.9548, Accuracy: 0.3649
# Validation Loss: 1.9860, Validation Accuracy: 0.3562, F1 Score: 0.0525
# Epoch 11 - Loss: 1.9591, Accuracy: 0.3649
# Validation Loss: 2.0401, Validation Accuracy: 0.3219, F1 Score: 0.0722
# Epoch 12 - Loss: 1.9414, Accuracy: 0.3557
# Validation Loss: 1.9708, Validation Accuracy: 0.3630, F1 Score: 0.0533
# Epoch 13 - Loss: 1.9064, Accuracy: 0.3748
# Validation Loss: 1.9172, Validation Accuracy: 0.3973, F1 Score: 0.1116
# Epoch 14 - Loss: 1.8587, Accuracy: 0.3908
# Validation Loss: 2.8148, Validation Accuracy: 0.1575, F1 Score: 0.0600
# Epoch 15 - Loss: 1.7350, Accuracy: 0.4153
# Validation Loss: 1.8806, Validation Accuracy: 0.3836, F1 Score: 0.1621
# Epoch 16 - Loss: 1.6079, Accuracy: 0.4298
# Validation Loss: 1.6573, Validation Accuracy: 0.3699, F1 Score: 0.2007
# Epoch 17 - Loss: 1.3847, Accuracy: 0.5122
# Validation Loss: 1.2082, Validation Accuracy: 0.5616, F1 Score: 0.2840
# Epoch 18 - Loss: 1.1666, Accuracy: 0.5863
# Validation Loss: 1.2711, Validation Accuracy: 0.5890, F1 Score: 0.3164
# Epoch 19 - Loss: 0.9934, Accuracy: 0.6351
# Validation Loss: 0.8368, Validation Accuracy: 0.7192, F1 Score: 0.5187
# Epoch 20 - Loss: 0.9161, Accuracy: 0.6649
# Validation Loss: 0.7757, Validation Accuracy: 0.7123, F1 Score: 0.5221
# Epoch 21 - Loss: 0.7070, Accuracy: 0.7550
# Validation Loss: 0.6209, Validation Accuracy: 0.7808, F1 Score: 0.6538
# Epoch 22 - Loss: 0.5673, Accuracy: 0.8000
# Validation Loss: 0.8504, Validation Accuracy: 0.7123, F1 Score: 0.6104
# Epoch 23 - Loss: 0.4583, Accuracy: 0.8267
# Validation Loss: 0.6640, Validation Accuracy: 0.7671, F1 Score: 0.6823
# Epoch 24 - Loss: 0.3578, Accuracy: 0.8733
# Validation Loss: 0.7634, Validation Accuracy: 0.8014, F1 Score: 0.7248
# Epoch 25 - Loss: 0.2861, Accuracy: 0.9015
# Validation Loss: 0.7121, Validation Accuracy: 0.8014, F1 Score: 0.7259
# Epoch 26 - Loss: 0.1978, Accuracy: 0.9382
# Validation Loss: 0.4462, Validation Accuracy: 0.8630, F1 Score: 0.8004
# Epoch 27 - Loss: 0.2781, Accuracy: 0.9000
# Validation Loss: 0.6011, Validation Accuracy: 0.8151, F1 Score: 0.7194
# Epoch 28 - Loss: 0.1163, Accuracy: 0.9573
# Validation Loss: 0.3424, Validation Accuracy: 0.9041, F1 Score: 0.8538
# Epoch 29 - Loss: 0.0699, Accuracy: 0.9756
# Validation Loss: 0.2735, Validation Accuracy: 0.9110, F1 Score: 0.8613
# Epoch 30 - Loss: 0.1317, Accuracy: 0.9550
# Validation Loss: 0.3676, Validation Accuracy: 0.9041, F1 Score: 0.8304
# Epoch 31 - Loss: 0.0714, Accuracy: 0.9771
# Validation Loss: 0.3074, Validation Accuracy: 0.9178, F1 Score: 0.8541
# Epoch 32 - Loss: 0.0252, Accuracy: 0.9931
# Validation Loss: 0.2759, Validation Accuracy: 0.9384, F1 Score: 0.9094
# Epoch 33 - Loss: 0.0291, Accuracy: 0.9885
# Validation Loss: 0.2697, Validation Accuracy: 0.9110, F1 Score: 0.8668
# Epoch 34 - Loss: 0.0192, Accuracy: 0.9954
# Validation Loss: 0.4019, Validation Accuracy: 0.9178, F1 Score: 0.8682
# Epoch 35 - Loss: 0.0536, Accuracy: 0.9832
# Validation Loss: 0.5739, Validation Accuracy: 0.8356, F1 Score: 0.7707
# Epoch 36 - Loss: 0.1453, Accuracy: 0.9519
# Validation Loss: 0.9914, Validation Accuracy: 0.7877, F1 Score: 0.6594
# Epoch 37 - Loss: 0.0484, Accuracy: 0.9885
# Validation Loss: 0.3397, Validation Accuracy: 0.9315, F1 Score: 0.8902
# Epoch 38 - Loss: 0.0103, Accuracy: 0.9977
# Validation Loss: 0.3521, Validation Accuracy: 0.9315, F1 Score: 0.9006
# Early stopping triggered after 5 epochs without improvement.
# Fold 7
# Epoch 1 - Loss: 2.5445, Accuracy: 0.3181
# Validation Loss: 2.3099, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 2 - Loss: 2.0386, Accuracy: 0.3524
# Validation Loss: 2.1045, Validation Accuracy: 0.3724, F1 Score: 0.0764
# Epoch 3 - Loss: 1.9766, Accuracy: 0.3646
# Validation Loss: 1.9723, Validation Accuracy: 0.3586, F1 Score: 0.0539
# Epoch 4 - Loss: 1.9549, Accuracy: 0.3654
# Validation Loss: 1.9625, Validation Accuracy: 0.3655, F1 Score: 0.0669
# Epoch 5 - Loss: 1.9566, Accuracy: 0.3654
# Validation Loss: 2.0014, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 6 - Loss: 1.9437, Accuracy: 0.3616
# Validation Loss: 1.9277, Validation Accuracy: 0.3655, F1 Score: 0.0667
# Epoch 7 - Loss: 1.9389, Accuracy: 0.3623
# Validation Loss: 1.9425, Validation Accuracy: 0.3793, F1 Score: 0.0956
# Epoch 8 - Loss: 1.9292, Accuracy: 0.3623
# Validation Loss: 2.0491, Validation Accuracy: 0.3724, F1 Score: 0.0788
# Epoch 9 - Loss: 1.9183, Accuracy: 0.3684
# Validation Loss: 1.8773, Validation Accuracy: 0.3931, F1 Score: 0.1016
# Epoch 10 - Loss: 1.9030, Accuracy: 0.3631
# Validation Loss: 1.9943, Validation Accuracy: 0.3724, F1 Score: 0.0828
# Epoch 11 - Loss: 1.8914, Accuracy: 0.3593
# Validation Loss: 2.0577, Validation Accuracy: 0.3655, F1 Score: 0.0535
# Epoch 12 - Loss: 1.8296, Accuracy: 0.3577
# Validation Loss: 1.8419, Validation Accuracy: 0.3862, F1 Score: 0.0937
# Epoch 13 - Loss: 1.7559, Accuracy: 0.3921
# Validation Loss: 1.7022, Validation Accuracy: 0.4345, F1 Score: 0.1957
# Epoch 14 - Loss: 1.6495, Accuracy: 0.4340
# Validation Loss: 1.7341, Validation Accuracy: 0.4552, F1 Score: 0.2490
# Epoch 15 - Loss: 1.5907, Accuracy: 0.4714
# Validation Loss: 1.6408, Validation Accuracy: 0.5034, F1 Score: 0.2619
# Epoch 16 - Loss: 1.4561, Accuracy: 0.5202
# Validation Loss: 1.4406, Validation Accuracy: 0.5241, F1 Score: 0.3217
# Epoch 17 - Loss: 1.2990, Accuracy: 0.5637
# Validation Loss: 1.4935, Validation Accuracy: 0.5379, F1 Score: 0.3459
# Epoch 18 - Loss: 1.1336, Accuracy: 0.5934
# Validation Loss: 1.1244, Validation Accuracy: 0.6000, F1 Score: 0.4651
# Epoch 19 - Loss: 0.9779, Accuracy: 0.6529
# Validation Loss: 1.1102, Validation Accuracy: 0.5793, F1 Score: 0.4112
# Epoch 20 - Loss: 0.8802, Accuracy: 0.6888
# Validation Loss: 0.8700, Validation Accuracy: 0.6828, F1 Score: 0.5644
# Epoch 21 - Loss: 0.6954, Accuracy: 0.7551
# Validation Loss: 1.0794, Validation Accuracy: 0.6621, F1 Score: 0.5560
# Epoch 22 - Loss: 0.5988, Accuracy: 0.7956
# Validation Loss: 1.0705, Validation Accuracy: 0.6621, F1 Score: 0.5622
# Epoch 23 - Loss: 0.4974, Accuracy: 0.8238
# Validation Loss: 0.7759, Validation Accuracy: 0.7724, F1 Score: 0.6706
# Epoch 24 - Loss: 0.3555, Accuracy: 0.8818
# Validation Loss: 0.8801, Validation Accuracy: 0.7517, F1 Score: 0.6894
# Epoch 25 - Loss: 0.3447, Accuracy: 0.8795
# Validation Loss: 0.5613, Validation Accuracy: 0.8207, F1 Score: 0.7714
# Epoch 26 - Loss: 0.2279, Accuracy: 0.9252
# Validation Loss: 0.3838, Validation Accuracy: 0.8621, F1 Score: 0.8079
# Epoch 27 - Loss: 0.1837, Accuracy: 0.9405
# Validation Loss: 1.1655, Validation Accuracy: 0.6759, F1 Score: 0.5230
# Epoch 28 - Loss: 0.1550, Accuracy: 0.9413
# Validation Loss: 0.5116, Validation Accuracy: 0.8690, F1 Score: 0.8164
# Epoch 29 - Loss: 0.1130, Accuracy: 0.9596
# Validation Loss: 0.7518, Validation Accuracy: 0.7862, F1 Score: 0.7190
# Epoch 30 - Loss: 0.1844, Accuracy: 0.9352
# Validation Loss: 0.9833, Validation Accuracy: 0.7517, F1 Score: 0.7343
